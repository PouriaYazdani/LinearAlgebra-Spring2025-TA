# %% [markdown]
# ## Part A - Linear Transformations of Vectors

# %%
import numpy as np
import matplotlib.pyplot as plt

def generate_grid_points(n_points, grid_range):
    # TODO: Implement grid generation logic (use np.linspace and np.meshgrid)
    pass

def plot_points(points, title, grid_range):
    # TODO: Implement plotting (use plt.scatter, set axis limits as grid_range ± 1)
    pass

def get_transformation_matrices():
    """
    Define and return three transformation matrices:
      - A 45° rotation matrix.
      - A horizontal stretch matrix (scale x-axis by 2).
      - A general linear transformation matrix (e.g., including reflection/rotation/stretching).
    """
    # TODO: Define and return the three matrices.
    pass

def plot_transformed_vectors(n_points, grid_range):
    """
    Generate a grid of vectors, apply three different transformations,
    and plot the original and transformed sets of vectors.
        """
    # TODO: 
    # 1. Generate grid points using generate_grid_points.
    # 2. Retrieve transformation matrices using get_transformation_matrices.
    # 3. Apply each transformation to the grid points.
    # 4. Plot the original grid and each transformed grid using plot_points.
    pass

n_points = 400        # Total number of points (e.g., 400 = 20x20 grid)
grid_range = (-1, 1)  # Grid range for both x and y

# TODO: Call the plot_transformed_vectors function to plot transformed vectors.

# %% [markdown]
# ## Part B - Coordinate Representations

# %%
def get_coords_in_new_basis(T, x_std):
    """
    Compute the coordinates of x_std in the new basis defined by T.
    """
    # TODO
    pass

def plot_basis_and_vector(T, x_std, title="", grid_range=range(-2, 3)):
    """
    Plot the skewed grid defined by the new basis T, the basis vectors,
    and the vector x_std with its decomposition in the new basis.
    """
    # TODO
    pass

def show_vector_in_different_bases(x_std):
    """
    Wraps up above methods.
    """
    # TODO:
    # 1. Plot x_std in the standard basis using the identity matrix.
    # 2. Retrieve transformation matrices (e.g., 45° rotation, horizontal stretch,
    #    general linear mapping) from get_transformation_matrices(). (REUSE)
    # 3. Plot x_std in each of these new bases using plot_basis_and_vector().
    pass

# Example usage:
x_std = np.array([-1, 2])  # The vector in standard coordinates
show_vector_in_different_bases(x_std)

# %%
def convert_std_to_new(T, x_std):
    """
    Convert a vector from the Standard Basis to the New Basis defined by T.
    """
    print("=== Converting from Standard Basis to New Basis ===")
    print("Transformation matrix (T):")
    print(T)
    print("\nGiven vector in Standard Basis (x_std):")
    print(x_std)

    # TODO also write formula/s you used for this conversion
    # TODO perform the conversion and log
    
    pass

def convert_new_to_std(T, x_new):
    """
    Convert a vector from the New Basis back to the Standard Basis.
    """
    # Minimal log messages
    print("\nGiven coordinates in the New Basis (x_new):")
    print(x_new)
    # TODO also log formula/s you used for this conversion
    # TODO: Compute the standard coordinates using T
    print("\nComputed Standard Basis coordinates")
    print(x_std)
    print("====================================================\n")

    
    return x_std

def demonstrate_conversion(x_std):
    """
    Demonstrate conversion between coordinate representations.
    
    """
    # TODO: Use the provided get_transformation_matrices() to obtain matrices.
    R45, S_horiz, A_gen = get_transformation_matrices()
    
    # Sample vector in Standard Basis.
    
    print(">> Using 45° Rotation Basis:")
    # TODO
    
    print(">> Using Horizontal Stretch Basis:")
    # TODO
    
    print(">> Using General Linear Mapping Basis:")
    # TODO

demonstrate_conversion(np.array([1, 2]))

# %% [markdown]
# ## Part C - Rank Inspection in Tranformation Matrices

# %%
from mpl_toolkits.mplot3d import Axes3D

# 1. Domain Generation (2D or 3D)
def generate_grid_points(dim, n, value_range):
    """
    Generate a grid of points in R^dim.

    Returns:
        points : numpy.ndarray of shape (dim, n^dim)
            Each column is a point in R^dim.
    """
    # TODO: Implement domain generation logic for 2D and 3D.
    pass

def plot_points_custom(ax, points, title="", plot_lim=(-10, 10)):
    """
    Plot points on the provided axis with custom axis limits.
    ax(2D or 3D) is a Matplotlib subplot (axis) object. It represents a
    single plot area within a figure.
    """
    # TODO: 
    # You can determine dimension (2 or 3) from points.shape[0].
    pass


def get_rank_0_matrix_3x2():
    """
    Return a 3x2 zero matrix (rank 0).
    """
    # TODO: Return a 3x2 matrix of all zeros.
    pass

def get_rank_1_matrix_3x2():
    """
    Return a 3x2 matrix with rank 1 (dependent columns).
    """
    # TODO: Return a 3x2 matrix whose columns are multiples of each other.
    pass

def get_rank_2_matrix_3x2():
    """
    Return a 3x2 matrix with rank 2 (independent columns).
    """
    # TODO: Return a 3x2 matrix whose columns are linearly independent.
    pass

# TODO: Similarly define the other matrix construction methods for:
#       2x3 matrices (rank 0, 1, 2) and 3x3 matrices (rank 1, 2, 3).

# Transformation Pipeline for One Case
def run_case(matrices, n, grid_range=(-2, 2), plot_lim=(-10, 10), case_title=""):
    """
    For a list of matrices (with the same domain dimension),
    generate the domain, transform it, and plot the results in one row.
    
    The first subplot: original domain.
    Subsequent subplots: images of the domain under each matrix.

    Transformation of points happen here.
    """
    # TODO
    pass

# Run All Cases in a Unified Pipeline
def main():
    """
    Demonstrate how different-rank matrices affect the image of a grid in R^2 or R^3.
    """
    # TODO:
    pass

main()
